# %% [markdown]
# # Analysis and Feature Extraction Utilities - DEMO

# %% [markdown]
# **Feature Extraction Utilities**
# * Download Clip: Downloads open AI clip model and returns model object
# * Load Images: loads images from a given directory. Returns either an array or pillow object
# * Clip Predictor: returns dataframe of predictions based on image input and label input

# %% [markdown]
# **EDA Utilities**
# * dataset_info: provides the details of a dataframe for a cursory glance at its contents
# * sort_classes: counts the number of instances of each class within a dataset
# * data_distribution: returns the skew, kurtosis, and other distribution information
# * PCA_analysis: performs PCA analysis on a dataset
# * cluster_kmeans: performs a cluster analysis using kmeans
# * plot_results: plot setup for basic plots
# * plot_kcluster: plots results from cluster analysis
# * plot_pca: plots results from pca analysis

# %% [markdown]
# ## EDA Utilities Demo

# %% [markdown]
# **Determine the number of instances of each class in a dataset**

# %%
from utilities import sort_classes

folder_path = r"../data/license_plate_detection/train/labels"
classes = sort_classes(folder_path= folder_path)
print(classes)

# %% [markdown]
# **Create a histogram of pixel distribution**

# %%
from utilities import data_distribution
from utilities import load_images

folder_path_2 = r"../data/license_plate_detection/train/images"
images = load_images(folder_path_2)
imgs_only = images[0]
data_distribution(imgs_only)

# %% [markdown]
# **Get basic statistical data on a data frame**

# %%
from utilities import dataset_info
import numpy as np
import pandas as pd
imgs_df = pd.DataFrame(imgs_only)
corr = dataset_info(imgs_df)

# %% [markdown]
# **Perform PCA analysis**

# %%
from utilities import PCA_analysis
from utilities import cluster_kmeans
from utilities import plot_kcluster
from utilities import plot_pca

x_pca = PCA_analysis(num_components=3, img_arrays= imgs_only, num_clusters=3) 
print(x_pca)

# %% [markdown]
# ## Feature Extraction DEMO

# %%
import pandas as pd
from utilities import load_images, clip_predictor, download_clip

# define classifier models
classifier = download_clip()

# %% [markdown]
# **Define Sample Labels for vehicle type and color**

# %%
color_labels = ["white", "black", "red", "orange", "yellow", "green", "blue", "purple"]
vehicle_labels = ["car", "bus", "motorcycle", "license plate"]

# %% [markdown]
# **Load sample images from directory**

# %%
image_folder = r"../data/formatted/license_plate_detection/train/images"
image, fp = load_images(directory= image_folder, num_img= 1, img_obj= True)

# %% [markdown]
# **Predict label probability based on labels and input image(s)**

# %%
import pandas as pd

vehicle_list = []
val = clip_predictor(image, vehicle_labels, classifier)

val = val.astype(float).round(4)
print(val)

# %% [markdown]
# **Show Image and Probabilities for Sample Image**

# %%
import matplotlib.pyplot as plt
from PIL import Image
sample_image = Image.open(fp)
plt.imshow(sample_image)

# Define box properties
props = dict(boxstyle='round', facecolor='wheat', alpha=0.5)

# Add text box at (x=1.5, y=6)
w, h = sample_image.size
plt.text(0, h*.15, val, fontsize=12, bbox=props)
plt.xticks([])
plt.yticks([])
plt.show()

# %%
image_folder = r"../data/formatted/license_plate_detection/train/images"
results = load_images(directory= image_folder, num_img= 100, img_obj= True)

vehicle_list = []
for idx, item in enumerate(results):
    image, file_path = item[0], item[1]
    val = clip_predictor(image, vehicle_labels, classifier)
    val = val.astype(float).round(4)

    val["fp"] = file_path

    vehicle_list.append(val)

    pct_complete = idx/len(results)
    if pct_complete*100 % 10 == 0:
        print(f"{pct_complete*100:.2f}% Complete")

vehicle_df = pd.concat(vehicle_list)

vehicle_df.head(5)

# %% [markdown]
# **Save Results to CSV file**

# %%
import os
vehicle_df['top_label'] = vehicle_df.drop(columns = ["fp"]).idxmax(axis=1)
vehicle_df.to_csv(f"C:/Users/{os.getlogin()}/Downloads/vehicles_probabilities.csv")

# %% [markdown]
# **For large image sets, save predictions to a .csv file**

# %%
import matplotlib.pyplot as plt
from PIL import Image
import numpy as np

def plot_df(dataframe, col_label):
    cols = 3
    n = dataframe.shape[0]
    rows = (n + cols - 1) // cols
    fig, axes = plt.subplots(rows, cols, figsize = (12, rows * 3) )

    axes_flat = axes.flatten()

    for idx, row in dataframe.iterrows():
        axes_flat[idx].imshow(Image.open(row["fp"]))
        axes_flat[idx].set_xticks([])
        axes_flat[idx].set_yticks([])
        axes_flat[idx].set_title(f'Probability {row[col_label]:.2f}%')

    plt.show()

df_license_plate_only = vehicle_df[vehicle_df["top_label"] == "license plate"].reset_index()
plot_df(df_license_plate_only, "license plate")

# %%
df_motorcycle = vehicle_df[vehicle_df["top_label"] == "motorcycle"].reset_index()

plot_df(df_motorcycle, "motorcycle")
