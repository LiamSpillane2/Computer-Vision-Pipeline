# %%
from ultralytics import YOLO
from pathlib import Path

if __name__ == "__main__":
    path = Path(r"\data\license_plate_detection\data.yaml")

    model = YOLO("yolo26n.pt")
    results = model.train(data=path, epochs=14, imgsz=640, device='0')
