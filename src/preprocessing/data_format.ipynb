# %%
#import raw data from license plate recognition

#save as .csv file

#separate variables
    #5 columns
    #image_id = the corresponding image file 
    #x_cent = x centroid
    #y_cent = y centroid
    #height = height of bounding box
    #width = width of bounding box
