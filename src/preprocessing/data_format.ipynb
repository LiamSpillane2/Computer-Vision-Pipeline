# %%
from formatting_data import rename_and_copy_all
rename_and_copy_all(
    base_input_dir= r"C:\Users\Installer\Documents\Computer-Vision-Pipeline\data\license_plate_detection",
    base_output_dir= r"C:\Users\Installer\Documents\Computer-Vision-Pipeline\data\formatted\license_plate_detection",
    dataset= 'lp'
)

# %%
from formatting_data import rename_and_copy_all
rename_and_copy_all(
    base_input_dir= r"C:\Users\Installer\Documents\Computer-Vision-Pipeline\data\weld_defects",
    base_output_dir= r"C:\Users\Installer\Documents\Computer-Vision-Pipeline\data\formatted\weld_defects",
    dataset = 'wd'
)

# %%
from formatting_data import rename_copy_and_add_headers_all
rename_copy_and_add_headers_all(
    base_input_dir = r"C:\Users\Installer\Documents\Computer-Vision-Pipeline\data\license_plate_detection",
    base_output_dir = r"C:\Users\Installer\Documents\Computer-Vision-Pipeline\data\formatted\license_plate_detection",
    headers = "class x_center y_center width height",  
    dataset = 'lp'
)

# %%
from formatting_data import corners_to_yolo
from formatting_data import convert_labels_all

convert_labels_all(
  base_input_dir = r"C:\Users\Installer\Documents\Computer-Vision-Pipeline\data\weld_defects",  
  base_output_dir = r"C:\Users\Installer\Documents\Computer-Vision-Pipeline\data\formatted\weld_defects",
  dataset= "wd"
)
